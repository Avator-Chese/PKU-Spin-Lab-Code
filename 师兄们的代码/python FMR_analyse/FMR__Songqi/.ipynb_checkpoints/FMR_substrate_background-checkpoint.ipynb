# %%
import numpy as np
import pandas as pd
import sys 
import matplotlib.pyplot as plt
import sys
sys.path.append('E:\doc\python')
import sqa
reload(sqa) 
# %matplotlib qt

# %%
temp='300'
folder='I:\\YIG'
filename='\\temp'+temp+'_S21.txt'

data_background=sqa.fmr_load_data(folder+filename)
background=sqa.fmr_load_data('I:\\YIG\\temp300_S21 background.txt')
table_fitting_para=sqa.origin_creat_table(temp+'fit_para')
longname_unit_comment1=[['sysmetrical height','',''],['resonance field','',''],['half linewidth','',''],['asysmetrical height','',''],
                        ['linear slope','',''],['constant','','']]
data=sqa.fmr_substrate_background(data_background,background)
table_temp=sqa.origin_creat_table(temp+'substracted_data')
sqa.origin_get_array(table_temp,np.array(data.index.values,ndmin=2).transpose(),position=[0,0],longname_unit_comment=[['H','','']])
sqa.origin_get_array(table_temp,data.values,position=[0,1])

n=0
for i in data.columns:
    frequency=float(i[1:])
    
    figname='\\temp'+temp+'freq'+str(float(i[1:])/1e9)+'_S21.png'
    figure_path=folder+figname
    print figure_path
    a=sqa.fmr_select_frequency(data,frequency)
    a_new=a.values
    #a_new=sqa.substrate_background_from_one_curve(a.index.values,a.values)
    fitting_para=sqa.fit_one_curve(a.index.values,a_new,figure_path=figure_path)
    #print parameters
    print [n,0],frequency
    sqa.origin_get_array(table_fitting_para,frequency,position=[n,0],longname_unit_comment=[['frequency(Hz)','','']])
    sqa.origin_get_array(table_fitting_para,fitting_para,position=[n,1],longname_unit_comment=longname_unit_comment1)
    n=n+1
    #current_figure=
    #plt.gcf()
    #plt.savefig(folder+figname)
# Out:
# I:\YIG\temp300freq1.0_S21.png
#
# 		no point => ok
# 		1 point => center
# 		3 point => limit the left and right width
# 		>3 point => give up
#
#
# 		no point => ok
# 		1 point => center
# 		3 point => limit the left and right width
# 		>3 point => give up
#
# [0, 0] 1000000000.0
# I:\YIG\temp300freq1.5_S21.png
#
# 		no point => ok
# 		1 point => center
# 		3 point => limit the left and right width
# 		>3 point => give up
#
#
# 		no point => ok
# 		1 point => center
# 		3 point => limit the left and right width
# 		>3 point => give up
#
# [1, 0] 1500000000.0
# I:\YIG\temp300freq2.0_S21.png
#
# 		no point => ok
# 		1 point => center
# 		3 point => limit the left and right width
# 		>3 point => give up
#
#
# 		no point => ok
# 		1 point => center
# 		3 point => limit the left and right width
# 		>3 point => give up
#
# [2, 0] 2000000000.0
# I:\YIG\temp300freq2.5_S21.png
#
# 		no point => ok
# 		1 point => center
# 		3 point => limit the left and right width
# 		>3 point => give up
#
# ...

# %%
temp='150'
folder='I:\\6 0.35\\temperature dependence'
filename='\\temp'+temp+'_S21.txt'

data_background=sqa.fmr_load_data(folder+filename)
background_new=sqa.fmr_load_data('I:\\temperature dependence background 2\\temp'+temp+'_S21.txt')
background_old=sqa.fmr_load_data('I:\\temperature dependence background\\temp'+temp+'_background_S21.txt')

# %%
data_new=sqa.fmr_substrate_background(data_background,background_new)
data_old=sqa.fmr_substrate_background(data_background,background_old)

# %%
sqa.fmr_select_frequency(data_new,5e9).plot()

# %%
sqa.fmr_select_frequency(data_old,5e9).plot()

# %%
data.index.size
