# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sqa
import math
import sys
sys.path.append('E:\\python\\python FMR_analyse')

# %matplotlib inline

# %%
data_position='E:\\project\\EuO\\FMR\\0518\\1st_temp=25k\\25k_new.txt'
data=sqa.fmr_load_data(data_position)

# %%
data
# Out:
#              +1.00000000000E+009  +1.50000000000E+009  +2.00000000000E+009  \
# H
# 0.000000               -3.022999            -3.733220            -4.643910
# 1.727557               -3.023293            -3.733449            -4.644207
# 4.171316               -3.023531            -3.733706            -4.644461
# 6.158005               -2.969177            -3.673583            -4.578904
# 7.994562               -3.023947            -3.734065            -4.644867
# 10.145483              -3.024178            -3.734240            -4.645061
# 12.048666              -3.024312            -3.734376            -4.645172
# 14.214820              -3.024389            -3.734418            -4.645265
# 16.064482              -3.024610            -3.734594            -4.645495
# 18.631031              -3.024708            -3.734749            -4.645630
# 20.577793              -3.024872            -3.734885            -4.645798
# ...

# %%
data.ix[data.index[np.arange(5783)%2==0]].to_csv('E:\\project\\EuO\\FMR\\0518\\1st_temp=25k\\25k_new.txt')
#将data.index转化为整数型处理；
#实际上，被整合的数据并不是简单的隔行穿插，而按照index的大小进行有序化排列的整合结果，所以把原始的两部分数据分开很难。

# %%
data.to_csv('E:\\project\\EuO\\FMR\\0518\\1st_temp=25k\\25k_new.txt')

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-54-7556a14882b9> in <module>()
# ----> 1 data1=pd.DataFrame(np.zeros().reshape((2897,39)),
#       2                    index=data.index%2==0,
#       3                    columns=data)
#       4 data1
#
# TypeError: Required argument 'shape' (pos 1) not found

# %%
i=0
data2=pd.DataFrame(np.zeros((2897,39)))
for i in range(2897): 
    
    data2[i,:] = data1[2*i,:]
else:
    print('yes')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-55-b1dffc349bd2> in <module>()
#       3 for i in range(2897):
#       4
# ----> 5     data2[i,:] = data1[2*i,:]
#       6 else:
#       7     print('yes')
#
# D:\python\lib\site-packages\pandas\core\series.pyc in __getitem__(self, key)
#     622             key = check_bool_indexer(self.index, key)
#     623
# --> 624         return self._get_with(key)
#     625
#     626     def _get_with(self, key):
#
# D:\python\lib\site-packages\pandas\core\series.pyc in _get_with(self, key)
#     635             if isinstance(key, tuple):
#     636                 try:
# --> 637                     return self._get_values_tuple(key)
#     638                 except:
#     639                     if len(key) == 1:
#
# D:\python\lib\site-packages\pandas\core\series.pyc in _get_values_tuple(self, key)
#     680
# ...

# %%
data2
# Out:
# array([[ -3.02299945,  -3.73321966,  -4.6439102 , ..., -14.79784414,
#         -14.39682903, -14.43476154],
#        [ -3.02329272,  -3.73344944,  -4.64420666, ..., -14.79853689,
#         -14.39691047, -14.43481591],
#        [ -3.02353068,  -3.73370588,  -4.64446091, ..., -14.79834606,
#         -14.39867809, -14.43466177],
#        ...,
#        [ -2.96203176,  -3.66745425,  -4.55005328, ..., -14.87569605,
#         -14.5083843 , -14.56928777],
#        [ -2.96209409,  -3.66752506,  -4.55011339, ..., -14.87523256,
#         -14.50802375, -14.56838326],
#        [ -2.96209586,  -3.66752677,  -4.55010611, ..., -14.87509041,
#         -14.50732302, -14.56903596]])

# %%
plt.imshow(data2,cmap=plt.cm.gray);plt.colorbar()

# %%
np.savetxt("E:\\project\\EuO\\FMR\\0518\\1st_temp=25k\\25k.txt",data2)
