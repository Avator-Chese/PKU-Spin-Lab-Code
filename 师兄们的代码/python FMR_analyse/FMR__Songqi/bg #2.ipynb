# %%
import pandas as pd
import numpy as np
import sys
import matplotlib.pyplot as plt
import sys
sys.path.append('E:\\python\\python FMR_analyse')
import sqa

# %matplotlib inline

# %%
filepath_data_background='C:\\Users\\user\\Desktop\\EuIG\\88 nm\\3st_T=300K_5dBm_S21.txt'
data_background=sqa.fmr_load_data(filepath_data_background)
filepath_background='E:\\project\\BG\\bg_403 #2\\bg#2\\temp200_background_S21.txt'
background=sqa.fmr_load_data(filepath_background)
#data=sqa.fmr_substrate_background(data_background,background)

# %%
sqa.fmr_mesh_dataframe(data_background)
#sqa.fmr_mesh_dataframe(background)
#sqa.fmr_mesh_dataframe(data)

# %%
fre5G=sqa.fmr_select_frequency(data_background,10e9)
plt.plot(fre5G,'.')

# %%
fre10G=sqa.fmr_select_frequency(data,10e9)
plt.plot(fre10G,'.')

# %%
fre12G=sqa.fmr_select_frequency(data,12e9)
plt.plot(fre12G,'.')

# %%
fre15G=sqa.fmr_select_frequency(data,15e9)
plt.plot(fre15G,'.')

# %%
fre17G=sqa.fmr_select_frequency(data,17e9)
plt.plot(fre17G,'.')

# %%
fre20G=sqa.fmr_select_frequency(data,20e9)
plt.plot(fre20G,'.')

# %%
data.to_csv('E:\\project\\EuO\\FMR\\0411\\50k-bg west\\50k_data-bg.txt')
